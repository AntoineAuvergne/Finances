# %% [markdown]
# Test d'extraction des infos des avis d'opéré boursorama

# %%
import pdfplumber

def extract_text_from_pdf(path):
    full_text = ""
    with pdfplumber.open(path) as pdf:
        for page in pdf.pages:
            full_text += page.extract_text() + "\n"
    return full_text

#text = extract_text_from_pdf("../../data/raw/Avis-d-opérés-13-11-2025-B-E-SP500-U-ETF-C.pdf")

# %%
display(text)
# Out:
# "Service Clientèle : 01 46 09 49 49 ou +33 146 09 49 49 depuis l'étranger, du lundi au vendredi de 8h à 20h et le samedi de 8h45 à 16h30 – www.boursobank.com\nBoursorama S.A. au capital de 51 171 597,60 € - RCS Nanterre 351 058 151 - TVA 69 351 058 151 - 44 rue Traversière - CS 80134 - 92772 Boulogne Billancourt Cedex\nAdresse du médiateur : Médiateur de l'AMF - 17, place de la Bourse - 75082 PARIS CEDEX 02\n000000\nF1\nP29367\n1/1\nOPERATION DE BOURSE\nle 13/11/2025\n(cid:128)(cid:10)(cid:97)(cid:40)(cid:66)(cid:59)(cid:82)(cid:27)(cid:69)(cid:25)(cid:75)(cid:27)(cid:116)(cid:50)(cid:109)(cid:2)(cid:92)(cid:33)(cid:74)(cid:7)(cid:102)(cid:23)(cid:77)(cid:43)(cid:128)(cid:41)(cid:84)(cid:33)(cid:77)(cid:2)(cid:113)(cid:7)(cid:65)(cid:26)(cid:77)(cid:33)(cid:122)(cid:59)(cid:75)(cid:55)(cid:89)(cid:12)(cid:76)(cid:33)(cid:93)(cid:39)(cid:73)(cid:43)\n000000 (cid:128)(cid:14)(cid:102)(cid:126)(cid:64)(cid:23)(cid:120)(cid:73)(cid:118)(cid:33)(cid:127)(cid:34)(cid:42)(cid:84)(cid:97)(cid:80)(cid:2)(cid:49)(cid:17)(cid:76)(cid:28)(cid:11)(cid:97)(cid:86)(cid:128)(cid:6)(cid:10)(cid:38)(cid:1)(cid:125)(cid:124)(cid:8)(cid:49)(cid:92)(cid:39)(cid:34)(cid:103)(cid:106)(cid:12)(cid:109)(cid:122)(cid:58)(cid:30)(cid:11)(cid:94)(cid:28)(cid:83)(cid:86)\nP29367 (cid:97)(cid:33)(cid:33)(cid:33)(cid:97)(cid:33)(cid:33)(cid:97)(cid:33)(cid:97)(cid:97)(cid:97)(cid:97)(cid:33)(cid:97)(cid:97)(cid:97)(cid:33)(cid:97)(cid:33)(cid:97)(cid:97)(cid:97)(cid:33)(cid:97)(cid:33)(cid:33)(cid:97)(cid:33)(cid:33)(cid:97)(cid:33)(cid:33)(cid:33)(cid:97)(cid:33)(cid:33)(cid:97)(cid:33)(cid:33)(cid:97)(cid:33)(cid:97)(cid:97)(cid:33)(cid:33)(cid:33)(cid:33)\nMR AUVERGNE ANTOINE\n7 RUE CAILLAUX\n75013 PARIS\nRéférences de votre compte titres\n40618 80314 00088604176 Compte PEA\nRésident Français\nACHAT COMPTANT\nACTION\nDate et heure\nlocale d'exécution Quantité Informations sur la valeur Informations sur l'exécution\n13/11/2025 27 BNPP EASY S&P 500 UC.EUR ETF Référence : 010101550227\nType d'ordre : au marché\n14:03:06\nCode ISIN : FR0011550185 Cours exécuté : 29,6702 EUR\nLieu d'exécution : EURONEXT PARIS\nMontant brut Commission Frais (¨) Montant net au débit de votre compte\n801,10 EUR 4,01 EUR 805,11 EUR\nSous réserve de bonne fin.\n(¨) Frais inhérents à la Taxe sur les Transactions Financières française\nCet avis ne tient pas compte des frais inhérents aux Taxes sur les Transactions Financières européennes (hors France), s'ils doivent s'appliquer.\nAA1\n"

# %%
import re

# Numéro de compte et nom raté
match_account = re.search(r'Compte\s([A-Z]+).*?(\d+)', text, re.DOTALL)
account_name = match_account.group(1) if match_account else None
account_number = match_account.group(2) if match_account else None

# Type d'opération (ACHAT/VENTE) check
operation_type = re.search(r'(ACHAT|VENTE)', text).group(1)

# Date et heure raté
date_match = re.search(r'(\d{2}/\d{2}/\d{4})\s+(\d{2}:\d{2}:\d{2})', text)
date, time = date_match.groups() if date_match else (None, None)

# Quantité et nom de valeur raté
quant_match = re.search(r'(\d+)\s+([A-Z0-9 &\.\-]+)\s+UC\.EUR ETF', text)
quantity = quant_match.group(1)
value_name = quant_match.group(2)

# ISIN
isin = re.search(r'Code ISIN\s*:\s*(\w+)', text).group(1)

# Type d'ordre check
order_type = re.search(r'Type d\'ordre\s*:\s*(.+)', text).group(1)

# Cours exécuté check
price = re.search(r'Cours exécuté\s*:\s*([\d,\.]+)\s*(EUR|USD)', text).groups()

# Montants (filtrés par devise) raté
amounts = re.findall(r'([\d,\.]+)\s*(EUR|USD)', text)
print("account_name :",account_name)
print("account_number :",account_number)
print("operation_type :",operation_type)
print("date,time :",date,time)
print("quantity :",quantity)
print("value_name :",value_name)
print("isin :",isin)
print("order_type :",order_type)
print("price :",price)
print("amounts :",amounts)
# Out:
# account_name : PEA
# account_number : 13
# operation_type : ACHAT
# date,time : None None
# quantity : 2025
# value_name : 27 BNPP EASY S&P 500
# isin : FR0011550185
# order_type : au marché
# price : ('29,6702', 'EUR')
# amounts : [('.', 'EUR'), ('29,6702', 'EUR'), ('801,10', 'EUR'), ('4,01', 'EUR'), ('805,11', 'EUR')]
